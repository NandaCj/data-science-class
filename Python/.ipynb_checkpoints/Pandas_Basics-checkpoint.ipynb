# %%
import pandas as pd
import numpy as np
import matplotlib

# %%
Dict = {'Age' : [20,30,40,50],
       'Salary':[1000, 2000, 3000, 5000]}

# %%
df = pd.DataFrame(Dict)

# %%
df
# Out:
#    Age  Salary
# 0   20    1000
# 1   30    2000
# 2   40    3000
# 3   50    5000

# %%
df.columns
# Out:
# Index(['Age', 'Salary'], dtype='object')

# %%
df.iloc[1]
# Out:
# Age         30
# Salary    2000
# Name: 1, dtype: int64

# %%
df['Age']
# Out:
# 0    20
# 1    30
# 2    40
# 3    50
# Name: Age, dtype: int64

# %%
df['Salary']
# Out:
# 0    1000
# 1    2000
# 2    3000
# 3    5000
# Name: Salary, dtype: int64

# %%
df.Age>20
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: Age, dtype: bool

# %%
df[df.Age > 20]
# Out:
#    Age  Salary
# 1   30    2000
# 2   40    3000
# 3   50    5000

# %%
df
# Out:
#    Age  Salary
# 0   20    1000
# 1   30    2000
# 2   40    3000
# 3   50    5000

# %%
file_path = '/home/nandagopalparamasivam/Downloads/Most-Recent-Cohorts-Scorecard-Elements.csv'

# %%
df1 = pd.read_csv(file_path)

# %%
df1.columns
# Out:
# Index(['UNITID', 'OPEID', 'OPEID6', 'INSTNM', 'CITY', 'STABBR', 'INSTURL',
#        'NPCURL', 'HCM2', 'PREDDEG',
#        ...
#        'OMAWDP8_NOTFIRSTTIME_POOLED_SUPP', 'OMENRUP_NOTFIRSTTIME_POOLED_SUPP',
#        'OMENRYP_FULLTIME_POOLED_SUPP', 'OMENRAP_FULLTIME_POOLED_SUPP',
#        'OMAWDP8_FULLTIME_POOLED_SUPP', 'OMENRUP_FULLTIME_POOLED_SUPP',
#        'OMENRYP_PARTTIME_POOLED_SUPP', 'OMENRAP_PARTTIME_POOLED_SUPP',
#        'OMAWDP8_PARTTIME_POOLED_SUPP', 'OMENRUP_PARTTIME_POOLED_SUPP'],
#       dtype='object', length=190)

# %%
df1.describe()
# Out:
#              UNITID         OPEID        OPEID6         HCM2      PREDDEG  \
# count  7.058000e+03  7.058000e+03   7058.000000  7058.000000  7058.000000
# mean   1.878890e+06  1.858900e+06  16662.088835     0.014452     1.833522
# std    6.983995e+06  3.324317e+06  14552.041302     0.119352     1.058940
# min    1.006540e+05  1.002000e+05   1002.000000     0.000000     0.000000
# 25%    1.739705e+05  3.221250e+05   3216.250000     0.000000     1.000000
# 50%    2.287020e+05  1.054202e+06  10506.000000     0.000000     2.000000
# 75%    4.505328e+05  3.019875e+06  30106.000000     0.000000     3.000000
# max    4.900540e+07  8.209884e+07  42698.000000     1.000000     4.000000
#
#            HIGHDEG      CONTROL       LOCALE         HBCU          PBI  ...  \
# count  7058.000000  7058.000000  6614.000000  6558.000000  6558.000000  ...
# mean      2.232785     2.128365    19.814484     0.015401     0.015401  ...
# std       1.343326     0.834608     9.537667     0.123151     0.123151  ...
# min       0.000000     1.000000    -3.000000     0.000000     0.000000  ...
# 25%       1.000000     1.000000    12.000000     0.000000     0.000000  ...
# 50%       2.000000     2.000000    21.000000     0.000000     0.000000  ...
# 75%       4.000000     3.000000    22.000000     0.000000     0.000000  ...
# max       4.000000     3.000000    43.000000     1.000000     1.000000  ...
#
#        CIPTFBSANNUAL3  CIPTFBSANNUAL4  CIPTFBSANNUAL5  CIPTFBSANNUAL6  \
# count     1566.000000     1213.000000      907.000000      702.000000
# mean      9362.583653     9115.697444     9184.749724     9289.220798
# std       5437.458883     5166.887059     5263.147027     5432.791707
# min          0.000000        0.000000      626.000000      650.000000
# 25%       5138.000000     4675.000000     4506.500000     4486.250000
# 50%       9050.000000     8312.000000     8989.000000     9056.000000
# 75%      12500.000000    13015.000000    12956.500000    13756.750000
# max      74990.000000    38614.000000    29894.000000    29078.000000
#
#            MTHCMP1      MTHCMP2      MTHCMP3      MTHCMP4     MTHCMP5  \
# count  2508.000000  1959.000000  1566.000000  1213.000000  907.000000
# mean     11.651515     9.547218     9.138570     9.614180   10.436604
# std       3.929648     4.926600     4.993346     5.443335    5.654620
# min       1.000000     1.000000     1.000000     1.000000    1.000000
# 25%       9.000000     6.000000     6.000000     6.000000    7.000000
# 50%      12.000000     9.000000     9.000000     9.000000    9.000000
# 75%      13.000000    12.000000    12.000000    12.000000   13.000000
# max      60.000000    48.000000    36.000000    45.000000   48.000000
#
#           MTHCMP6
# count  702.000000
# mean    10.571225
# std      5.349942
# min      1.000000
# 25%      8.000000
# 50%      9.000000
# 75%     12.000000
# max     36.000000
#
# [8 rows x 132 columns]

# %%
A = df1['OPEID']

# %%
df1[2:10:2]
# Out:
#    UNITID    OPEID  OPEID6                             INSTNM            CITY  \
# 2  100690  2503400   25034                 Amridge University      Montgomery
# 4  100724   100500    1005           Alabama State University      Montgomery
# 6  100760   100700    1007  Central Alabama Community College  Alexander City
# 8  100830   831000    8310    Auburn University at Montgomery      Montgomery
#
#   STABBR                    INSTURL  \
# 2     AL  www.amridgeuniversity.edu
# 4     AL              www.alasu.edu
# 6     AL               www.cacc.edu
# 8     AL                www.aum.edu
#
#                                               NPCURL  HCM2  PREDDEG  ...  \
# 2                   www2.amridgeuniversity.edu:9091/     0        3  ...
# 4  www.alasu.edu/cost-aid/forms/calculator/index....     0        3  ...
# 6         https://www.cacc.edu/net-price-calculator/     0        2  ...
# 8  www.aum.edu/current-students/financial-informa...     0        3  ...
#
#    OMAWDP8_NOTFIRSTTIME_POOLED_SUPP  OMENRUP_NOTFIRSTTIME_POOLED_SUPP  \
# 2                            0.4647                            0.1912
# 4                            0.4226                            0.0754
# 6                            0.2807                            0.3502
# 8                            0.4884                            0.2048
#
#    OMENRYP_FULLTIME_POOLED_SUPP  OMENRAP_FULLTIME_POOLED_SUPP  \
# 2                        0.0148                        0.3284
# 4                        0.0254                        0.5327
# 6                        0.0142                        0.3794
# 8                        0.0134                        0.4208
#
#    OMAWDP8_FULLTIME_POOLED_SUPP  OMENRUP_FULLTIME_POOLED_SUPP  \
# 2                        0.4391                        0.2177
# 4                        0.3133                        0.1286
# 6                        0.2206                        0.3858
# 8                         0.327                        0.2388
#
#    OMENRYP_PARTTIME_POOLED_SUPP  OMENRAP_PARTTIME_POOLED_SUPP  \
# 2                         0.028                        0.3645
# 4                         0.021                        0.5804
# 6                        0.0092                        0.3258
# 8                        0.0289                        0.3737
#
#   OMAWDP8_PARTTIME_POOLED_SUPP  OMENRUP_PARTTIME_POOLED_SUPP
# 2                       0.4486                        0.1589
# 4                       0.1678                        0.2308
# 6                       0.2769                        0.3881
# 8                       0.2352                        0.3622
#
# [4 rows x 190 columns]

# %%
type(A)
# Out:
# pandas.core.series.Series

# %%
# %matplotlib inline

df1.plot(x='OPEID', y='HCM2', kind='scatter')

# %%
df.plot(x='Age', y='Salary', kind='line')

# %%
Ages = df.Age.values

# %%
type(Ages)
# Out:
# numpy.ndarray

# %%
Ages.reshape(2,2)
# Out:
# array([[20, 30],
#        [40, 50]])

# %%
['col_'+str(i) for i in range(3)]
# Out:
# ['col_0', 'col_1', 'col_2']

# %%
df_r = pd.DataFrame(np.random.randn(10, 10), columns=['col_'+str(i) for i in range(10)])

# %%
df_r
# Out:
#       col_0     col_1     col_2     col_3     col_4     col_5     col_6  \
# 0  2.091977  1.627891  0.355133  0.018980  0.240137  1.110909 -0.491275
# 1  0.201500 -0.077215  0.408117  1.243936 -1.020735 -0.397078  0.572831
# 2  1.288272  0.747669 -0.511132 -0.005874  0.538476 -0.054772 -1.865317
# 3 -1.466719  0.881283 -1.088274  1.173062  0.576678  0.983654 -0.084304
# 4  0.174707  0.479505 -0.112850 -0.012763  0.982820 -0.450814  1.327770
# 5  0.382059 -0.178949  1.141665 -0.170649  0.322379  0.163508 -1.004242
# 6 -0.410511 -0.551876 -0.116084  0.721053 -0.086893  0.768247  0.460209
# 7  0.188641 -0.829268 -1.364066 -0.263089 -0.412808 -0.096978 -1.925204
# 8  0.124605 -0.389852  0.090437  2.011667  0.663524 -0.473774  0.803023
# 9 -0.023782 -0.839332  0.067649 -1.001169 -0.247879  0.588161 -0.392591
#
#       col_7     col_8     col_9
# 0  1.588976 -0.732390 -0.553373
# 1  0.699274  0.640075  2.135641
# 2  0.450669 -1.782314  0.450697
# 3 -1.280183  0.430705 -0.879051
# 4  0.020286 -0.646973  1.328481
# 5 -0.878769  0.078918 -0.096109
# 6  0.216207 -0.230584  1.197999
# 7 -0.448219 -0.173474  0.112256
# 8 -0.158003 -0.528036 -0.529133
# 9 -0.594246 -0.143083 -1.049610

# %%
for i in df_r.iteritems() :
    print(i)
# Out:
# ('col_0', 0    2.091977
# 1    0.201500
# 2    1.288272
# 3   -1.466719
# 4    0.174707
# 5    0.382059
# 6   -0.410511
# 7    0.188641
# 8    0.124605
# 9   -0.023782
# Name: col_0, dtype: float64)
# ('col_1', 0    1.627891
# 1   -0.077215
# 2    0.747669
# 3    0.881283
# 4    0.479505
# 5   -0.178949
# 6   -0.551876
# 7   -0.829268
# 8   -0.389852
# 9   -0.839332
# Name: col_1, dtype: float64)
# ('col_2', 0    0.355133
# 1    0.408117
# 2   -0.511132
# 3   -1.088274
# 4   -0.112850
# 5    1.141665
# 6   -0.116084
# 7   -1.364066
# 8    0.090437
# 9    0.067649
# Name: col_2, dtype: float64)
# ('col_3', 0    0.018980
# 1    1.243936
# 2   -0.005874
# 3    1.173062
# 4   -0.012763
# 5   -0.170649
# 6    0.721053
# 7   -0.263089
# 8    2.011667
# 9   -1.001169
# Name: col_3, dtype: float64)
# ('col_4', 0    0.240137
# 1   -1.020735
# 2    0.538476
# 3    0.576678
# 4    0.982820
# 5    0.322379
# 6   -0.086893
# 7   -0.412808
# 8    0.663524
# 9   -0.247879
# Name: col_4, dtype: float64)
# ('col_5', 0    1.110909
# 1   -0.397078
# 2   -0.054772
# 3    0.983654
# 4   -0.450814
# 5    0.163508
# 6    0.768247
# 7   -0.096978
# 8   -0.473774
# 9    0.588161
# Name: col_5, dtype: float64)
# ('col_6', 0   -0.491275
# 1    0.572831
# 2   -1.865317
# 3   -0.084304
# 4    1.327770
# 5   -1.004242
# 6    0.460209
# 7   -1.925204
# 8    0.803023
# 9   -0.392591
# Name: col_6, dtype: float64)
# ('col_7', 0    1.588976
# 1    0.699274
# 2    0.450669
# 3   -1.280183
# 4    0.020286
# 5   -0.878769
# 6    0.216207
# 7   -0.448219
# 8   -0.158003
# 9   -0.594246
# Name: col_7, dtype: float64)
# ('col_8', 0   -0.732390
# 1    0.640075
# 2   -1.782314
# 3    0.430705
# 4   -0.646973
# 5    0.078918
# 6   -0.230584
# 7   -0.173474
# 8   -0.528036
# 9   -0.143083
# Name: col_8, dtype: float64)
# ('col_9', 0   -0.553373
# 1    2.135641
# 2    0.450697
# 3   -0.879051
# 4    1.328481
# 5   -0.096109
# 6    1.197999
# 7    0.112256
# 8   -0.529133
# 9   -1.049610
# Name: col_9, dtype: float64)

# %%
for i in df_r.iterrows() :
    print(i)
# Out:
# (0, col_0    2.091977
# col_1    1.627891
# col_2    0.355133
# col_3    0.018980
# col_4    0.240137
# col_5    1.110909
# col_6   -0.491275
# col_7    1.588976
# col_8   -0.732390
# col_9   -0.553373
# Name: 0, dtype: float64)
# (1, col_0    0.201500
# col_1   -0.077215
# col_2    0.408117
# col_3    1.243936
# col_4   -1.020735
# col_5   -0.397078
# col_6    0.572831
# col_7    0.699274
# col_8    0.640075
# col_9    2.135641
# Name: 1, dtype: float64)
# (2, col_0    1.288272
# col_1    0.747669
# col_2   -0.511132
# col_3   -0.005874
# col_4    0.538476
# col_5   -0.054772
# col_6   -1.865317
# col_7    0.450669
# col_8   -1.782314
# col_9    0.450697
# Name: 2, dtype: float64)
# (3, col_0   -1.466719
# col_1    0.881283
# col_2   -1.088274
# col_3    1.173062
# col_4    0.576678
# col_5    0.983654
# col_6   -0.084304
# col_7   -1.280183
# col_8    0.430705
# col_9   -0.879051
# Name: 3, dtype: float64)
# (4, col_0    0.174707
# col_1    0.479505
# col_2   -0.112850
# col_3   -0.012763
# col_4    0.982820
# col_5   -0.450814
# col_6    1.327770
# col_7    0.020286
# col_8   -0.646973
# col_9    1.328481
# Name: 4, dtype: float64)
# (5, col_0    0.382059
# col_1   -0.178949
# col_2    1.141665
# col_3   -0.170649
# col_4    0.322379
# col_5    0.163508
# col_6   -1.004242
# col_7   -0.878769
# col_8    0.078918
# col_9   -0.096109
# Name: 5, dtype: float64)
# (6, col_0   -0.410511
# col_1   -0.551876
# col_2   -0.116084
# col_3    0.721053
# col_4   -0.086893
# col_5    0.768247
# col_6    0.460209
# col_7    0.216207
# col_8   -0.230584
# col_9    1.197999
# Name: 6, dtype: float64)
# (7, col_0    0.188641
# col_1   -0.829268
# col_2   -1.364066
# col_3   -0.263089
# col_4   -0.412808
# col_5   -0.096978
# col_6   -1.925204
# col_7   -0.448219
# col_8   -0.173474
# col_9    0.112256
# Name: 7, dtype: float64)
# (8, col_0    0.124605
# col_1   -0.389852
# col_2    0.090437
# col_3    2.011667
# col_4    0.663524
# col_5   -0.473774
# col_6    0.803023
# col_7   -0.158003
# col_8   -0.528036
# col_9   -0.529133
# Name: 8, dtype: float64)
# (9, col_0   -0.023782
# col_1   -0.839332
# col_2    0.067649
# col_3   -1.001169
# col_4   -0.247879
# col_5    0.588161
# col_6   -0.392591
# col_7   -0.594246
# col_8   -0.143083
# col_9   -1.049610
# Name: 9, dtype: float64)

# %%
unsorted_df = pd.DataFrame(np.random.randn(10,2),index=[1,4,6,2,3,5,9,8,0,7],columns = ['col2','col1'])

# %%
unsorted_df.sort_index(axis=1, inplace=True)

# %%
unsorted_df
# Out:
#        col1      col2
# 1  0.460740 -1.520890
# 4  0.578412  0.456879
# 6 -2.527459  1.621810
# 2  0.766509 -1.392949
# 3  0.381652 -0.961301
# 5 -0.894879 -1.756955
# 9  0.298055  1.023041
# 8  2.180974  1.812570
# 0 -0.500760  1.635851
# 7  0.262997  0.294569

# %%
name = 'Nanda_Gopal'

# %%
name.split('_')
# Out:
# ['Nanda', 'Gopal']

# %%
s = pd.Series(['Tom', 'William Rick', 'John', 'Alber@t', np.nan, '1234','SteveSmith'])

# %%
df_r.loc[:'col_1']
# Out:
#       col_0     col_1     col_2     col_3     col_4     col_5     col_6  \
# 0  2.091977  1.627891  0.355133  0.018980  0.240137  1.110909 -0.491275
# 1  0.201500 -0.077215  0.408117  1.243936 -1.020735 -0.397078  0.572831
# 2  1.288272  0.747669 -0.511132 -0.005874  0.538476 -0.054772 -1.865317
# 3 -1.466719  0.881283 -1.088274  1.173062  0.576678  0.983654 -0.084304
# 4  0.174707  0.479505 -0.112850 -0.012763  0.982820 -0.450814  1.327770
# 5  0.382059 -0.178949  1.141665 -0.170649  0.322379  0.163508 -1.004242
# 6 -0.410511 -0.551876 -0.116084  0.721053 -0.086893  0.768247  0.460209
# 7  0.188641 -0.829268 -1.364066 -0.263089 -0.412808 -0.096978 -1.925204
# 8  0.124605 -0.389852  0.090437  2.011667  0.663524 -0.473774  0.803023
# 9 -0.023782 -0.839332  0.067649 -1.001169 -0.247879  0.588161 -0.392591
#
#       col_7     col_8     col_9
# 0  1.588976 -0.732390 -0.553373
# 1  0.699274  0.640075  2.135641
# 2  0.450669 -1.782314  0.450697
# 3 -1.280183  0.430705 -0.879051
# 4  0.020286 -0.646973  1.328481
# 5 -0.878769  0.078918 -0.096109
# 6  0.216207 -0.230584  1.197999
# 7 -0.448219 -0.173474  0.112256
# 8 -0.158003 -0.528036 -0.529133
# 9 -0.594246 -0.143083 -1.049610

# %%
df = pd.DataFrame(np.random.randn(5, 3), index=['a', 'c', 'e', 'f',
'h'],columns=['one', 'two', 'three'])

df = df.reindex(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])

df
# Out:
#         one       two     three
# a -0.209126 -1.161216 -0.548692
# b       NaN       NaN       NaN
# c -0.840499 -0.051073 -0.794478
# d       NaN       NaN       NaN
# e -0.119508  0.999481  0.495057
# f  1.272402 -0.456122 -0.356215
# g       NaN       NaN       NaN
# h -0.857871 -1.758314  0.162596

# %%
df.isnull()
# Out:
#      one    two  three
# a  False  False  False
# b   True   True   True
# c  False  False  False
# d   True   True   True
# e  False  False  False
# f  False  False  False
# g   True   True   True
# h  False  False  False

# %%
df['one'].fillna(45)
# Out:
# a    -0.209126
# b    45.000000
# c    -0.840499
# d    45.000000
# e    -0.119508
# f     1.272402
# g    45.000000
# h    -0.857871
# Name: one, dtype: float64

# %% [markdown]
# Links [https://pandas.pydata.org/pandas-docs/stable/reference/io.html]

# %%
df_r = pd.Dataf
