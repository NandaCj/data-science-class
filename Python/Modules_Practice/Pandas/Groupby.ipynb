# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import psycopg2

# %%
connection = psycopg2.connect(user = "postgres",
                                  password = "postgres",
                                  host = "127.0.0.1",
                                  port = "5432",
                                  database = "stock")
cursor = connection.cursor()

# %%
df = pd.read_sql("select * from sector", connection)

# %%
df = pd.read_sql('select * from sector', connection)
df['sector'] = df['sector'].str.rstrip("\n")
df.head()
# Out:
#    stock_id                                  industry              sector
# 0    3PLAND                               Real Estate         Real Estate
# 1    5PAISA             Broking &amp; Allied Services  Financial Services
# 2   63MOONS  IT Consulting &amp; Software - Small Cap         IT Software
# 3   8KMILES  IT Consulting &amp; Software - Small Cap         IT Software
# 4  A2ZINFRA                             Miscellaneous       Miscellaneous

# %%
df_g = df.groupby('industry').count().reset_index()

# %%
df_g.head()
# Out:
#                         industry  stock_id  sector
# 0                                        4       4
# 1                            AMC         2       2
# 2  Abrasives And Grinding Wheels         4       4
# 3       Agro Processing - Others         1       1
# 4               Air Conditioners         4       4

# %%
df_g.sort_values('stock_id', ascending=False)
# Out:
#                                      industry  stock_id  sector
# 171                           Pharma - Indian        70      70
# 191                               Real Estate        47      47
# 67             Construction &amp; Contracting        36      36
# 120  IT Consulting &amp; Software - Small Cap        34      34
# 25                         Auto Ancl - Others        34      34
# ..                                        ...       ...     ...
# 68             Construction &amp; Engineering         1       1
# 65                                Compressors         1       1
# 59     Chemicals - Organic - Maleic Anhydride         1       1
# 210                      Steel - GP/GC Sheets         1       1
# 125             Industrial Equipment - Others         1       1
#
# [250 rows x 3 columns]

# %%
df[df['industry'] == 'Pharma - Indian']
# Out:
#         stock_id         industry             sector
# 5     AARTIDRUGS  Pharma - Indian  Pharmaceuticals\n
# 6       AARTIIND  Pharma - Indian  Pharmaceuticals\n
# 39    AJANTPHARM  Pharma - Indian  Pharmaceuticals\n
# 44    ALBERTDAVD  Pharma - Indian  Pharmaceuticals\n
# 50         ALKEM  Pharma - Indian  Pharmaceuticals\n
# ...          ...              ...                ...
# 1540    VENUSREM  Pharma - Indian  Pharmaceuticals\n
# 1567  VIVIMEDLAB  Pharma - Indian  Pharmaceuticals\n
# 1580     WANBURY  Pharma - Indian  Pharmaceuticals\n
# 1598  WOCKPHARMA  Pharma - Indian  Pharmaceuticals\n
# 1617        ZOTA  Pharma - Indian  Pharmaceuticals\n
#
# [70 rows x 3 columns]

# %%
df_g.sort_values('stock_id',ascending=True).plot('industry', 'stock_id', kind='barh', figsize=(10,50))

# %%
df_s = df.groupby('sector').count().reset_index()
df_s.sort_values('stock_id',ascending=True).plot('sector', 'stock_id', kind='barh', figsize=(10,50))

# %%
df[df['sector'] == 'Rubber']
# Out:
#        stock_id                           industry  sector
# 78   APCOTEXIND  Rubber Processing/Rubber Products  Rubber
# 398   ELGIRUBCO  Rubber Processing/Rubber Products  Rubber
# 527      GRPLTD  Rubber Processing/Rubber Products  Rubber
# 551  HARRMALAYA        Plantations - Rubber/Others  Rubber

# %%
df[df['industry'] == 'Real Estate']
# Out:
#         stock_id     industry       sector
# 0         3PLAND  Real Estate  Real Estate
# 40        AJMERA  Real Estate  Real Estate
# 46        ALCHEM  Real Estate  Real Estate
# 64       AMJLAND  Real Estate  Real Estate
# 66      ANANTRAJ  Real Estate  Real Estate
# 72      ANSALAPI  Real Estate  Real Estate
# 73      ANSALHSG  Real Estate  Real Estate
# 92       ARIHANT  Real Estate  Real Estate
# 93    ARIHANTSUP  Real Estate  Real Estate
# 103     ARVSMART  Real Estate  Real Estate
# 108      ASHIANA  Real Estate  Real Estate
# 189   BHAGYAPROP  Real Estate  Real Estate
# 224      BRIGADE  Real Estate  Real Estate
# 304    COUNCODOS  Real Estate  Real Estate
# 329     DBREALTY  Real Estate  Real Estate
# 362          DLF  Real Estate  Real Estate
# 401    EMAMIREAL  Real Estate  Real Estate
# 460   GANESHHOUC  Real Estate  Real Estate
# 469       GEECEE  Real Estate  Real Estate
# 505   GODREJPROP  Real Estate  Real Estate
# 565         HDIL  Real Estate  Real Estate
# ...
