# %%
import os
import tensorflow as tf

cur_dir = os.getcwd()
Storage = os.path.join(cur_dir, 'Storage.ckpt.data-00000-of-00001')

# %%
# saver = tf.train.Saver()
saver = tf.train.import_meta_graph('Storage.ckpt.meta')
with tf.Session() as sess:
    saver.restore(sess, Storage)
# Out:
# ---------------------------------------------------------------------------
# DataLossError                             Traceback (most recent call last)
# c:\users\ranjith\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#
# c:\users\ranjith\python\python35\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#
# c:\users\ranjith\python\python35\lib\contextlib.py in __exit__(self, type, value, traceback)
#      65             try:
# ---> 66                 next(self.gen)
#      67             except StopIteration:
#
# ...
