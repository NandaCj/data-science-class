# %%
# %matplotlib inline 
import pandas as pd 
import numpy as np
from math import sqrt

# Visualization Modules
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.tree import plot_tree
# plot_tree(dt_reg) # For Large Datasets Tree Graph needs more visualization techniques

#Scipy Maths Models
import statsmodels.api as sm
from scipy import stats

# Machine Learning Training Modules
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import SGDRegressor

# Model Evaluation Metrics
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import r2_score

# Model Selection and Validation Methods
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold, ShuffleSplit

# Preprocessing Modules 
from sklearn.preprocessing import PolynomialFeatures

# %%
data_file = 'ExceptionAnalysis.xlsx' # make sure the path of the file is correct
df = pd.read_excel(data_file)
df.head()
# Out:
#                         MessageType ProcessedDate  ExceptionCount
# 0        APPortalAccessionEditEvent    30-09-2019              39
# 1                 HelixTestAddEvent    30-09-2019              51
# 2                HelixTestStopEvent    30-09-2019               4
# 3         APPortalDistributionEvent    30-09-2019             124
# 4  WebAppsInternalTechCompleteEvent    30-09-2019               3

# %% [markdown]
# # Message Type Grouping

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 259 entries, 0 to 258
# Data columns (total 3 columns):
# MessageType       259 non-null object
# ProcessedDate     259 non-null object
# ExceptionCount    259 non-null int64
# dtypes: int64(1), object(2)
# memory usage: 6.2+ KB

# %%
df.groupby('MessageType').count()
# Out:
#                                   ProcessedDate  ExceptionCount
# MessageType
# APPortalAccessionAddEvent                    43              43
# APPortalAccessionEditEvent                   37              37
# APPortalDistributionEvent                    44              44
# APPortalPatientEditEvent                      1               1
# ConfirmationEvent                            25              25
# HelixTestAddEvent                            44              44
# HelixTestStopEvent                           37              37
# VirtuosoSpecimenReleaseEvent                  1               1
# WebAppsInternalTechCompleteEvent             27              27

# %%
set(list(df.MessageType.values))
# Out:
# {'APPortalAccessionAddEvent',
#  'APPortalAccessionEditEvent',
#  'APPortalDistributionEvent',
#  'APPortalPatientEditEvent',
#  'ConfirmationEvent',
#  'HelixTestAddEvent',
#  'HelixTestStopEvent',
#  'VirtuosoSpecimenReleaseEvent',
#  'WebAppsInternalTechCompleteEvent'}

# %%
df[df['MessageType'] == 'HelixTestAddEvent']
# Out:
#            MessageType ProcessedDate  ExceptionCount
# 1    HelixTestAddEvent    30-09-2019              51
# 8    HelixTestAddEvent    29-09-2019               1
# 14   HelixTestAddEvent    28-09-2019              47
# 17   HelixTestAddEvent    27-09-2019              77
# 23   HelixTestAddEvent    26-09-2019              77
# 35   HelixTestAddEvent    25-09-2019              78
# 38   HelixTestAddEvent    24-09-2019              56
# 45   HelixTestAddEvent    23-09-2019              47
# 52   HelixTestAddEvent    22-09-2019               5
# 57   HelixTestAddEvent    21-10-2019              31
# 61   HelixTestAddEvent    21-09-2019              47
# 66   HelixTestAddEvent    20-10-2019               3
# 75   HelixTestAddEvent    20-09-2019              99
# 78   HelixTestAddEvent    19-10-2019              80
# 86   HelixTestAddEvent    19-09-2019              86
# 92   HelixTestAddEvent    18-10-2019             107
# 97   HelixTestAddEvent    18-09-2019              73
# ...
